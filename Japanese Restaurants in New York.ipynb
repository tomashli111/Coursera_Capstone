# %% [markdown]
# Importing the required dependancies:

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import requests
from bs4 import BeautifulSoup
# !pip install geocoder
import geocoder
import os

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


print('Libraries imported.')
# Out:
# Requirement already satisfied: geocoder in /opt/anaconda3/lib/python3.8/site-packages (1.38.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: ratelim in /opt/anaconda3/lib/python3.8/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.8/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.8/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.8/site-packages (from ratelim->geocoder) (4.4.2)
# Libraries imported.

# %%
def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

# %%
CLIENT_ID = 'KTLBN10PJAGAA2KUHO22M2MY0NZGEDKWPXJOIBBHDAZWGIXS' # your Foursquare ID
CLIENT_SECRET = '1WVQXWVNKQA0OGMLWGSA40NRD1G2U2TL1IGEULT1MIGEK5EQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KTLBN10PJAGAA2KUHO22M2MY0NZGEDKWPXJOIBBHDAZWGIXS
# CLIENT_SECRET:1WVQXWVNKQA0OGMLWGSA40NRD1G2U2TL1IGEULT1MIGEK5EQ

# %%
def get_venues(lat,lng): 
    #set variables
    radius=1000
    LIMIT=100
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    new_york_data = pd.DataFrame(columns=column_names)
    
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
    
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
    return new_york_data

# %%
new_york_data=get_new_york_data()

# %%
new_york_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
new_york_data.shape
# Out:
# (306, 4)

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name']
japanese_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in new_york_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    japanese_resturants=venues[venues['Category']=='Japanese Restaurant']   
    print('(',count,'/',len(new_york_data),')','Japanese Resturants in '+Neighborhood+', '+Borough+':'+str(len(japanese_resturants)))
    for resturant_detail in japanese_resturants.values.tolist():
        id, name , category=resturant_detail
        japanese_rest_ny = japanese_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Japanese Resturants in Wakefield, Bronx:0
# ( 2 / 306 ) Japanese Resturants in Co-op City, Bronx:0
# ( 3 / 306 ) Japanese Resturants in Eastchester, Bronx:0
# ( 4 / 306 ) Japanese Resturants in Fieldston, Bronx:0
# ( 5 / 306 ) Japanese Resturants in Riverdale, Bronx:2
# ( 6 / 306 ) Japanese Resturants in Kingsbridge, Bronx:2
# ( 269 / 306 ) Japanese Resturants in Concourse Village, Bronx:0
# ( 270 / 306 ) Japanese Resturants in Mount Eden, Bronx:0
# ( 271 / 306 ) Japanese Resturants in Mount Hope, Bronx:0
# ( 272 / 306 ) Japanese Resturants in Sutton Place, Manhattan:0
# ( 273 / 306 ) Japanese Resturants in Hunters Point, Queens:3
# ( 274 / 306 ) Japanese Resturants in Turtle Bay, Manhattan:2
# ( 275 / 306 ) Japanese Resturants in Tudor City, Manhattan:4
# ( 276 / 306 ) Japanese Resturants in Stuyvesant Town, Manhattan:1
# ( 277 / 306 ) Japanese Resturants in Flatiron, Manhattan:3
# ( 278 / 306 ) Japanese Resturants in Sunnyside Gardens, Queens:1
# ( 279 / 306 ) Japanese Resturants in Blissville, Queens:0
# ( 280 / 306 ) Japanese Resturants in Fulton Ferry, Brooklyn:1
# ( 281 / 306 ) Japanese Resturants in Vinegar Hill, Brooklyn:1
# ( 282 / 306 ) Japanese Resturants in Weeksville, Brooklyn:0
# ( 283 / 306 ) Japanese Resturants in Broadway Junction, Brooklyn:0
# ( 284 / 306 ) Japanese Resturants in Dumbo, Brooklyn:2
# ( 285 / 306 ) Japanese Resturants in Manor Heights, Staten Island:0
# ( 286 / 306 ) Japanese Resturants in Willowbrook, Staten Island:0
# ( 287 / 306 ) Japanese Resturants in Sandy Ground, Staten Island:0
# ( 288 / 306 ) Japanese Resturants in Egbertville, Staten Island:0
# ( 289 / 306 ) Japanese Resturants in Roxbury, Queens:0
# ( 290 / 306 ) Japanese Resturants in Homecrest, Brooklyn:2
# ( 291 / 306 ) Japanese Resturants in Middle Village, Queens:0
# ( 292 / 306 ) Japanese Resturants in Prince's Bay, Staten Island:0
# ( 293 / 306 ) Japanese Resturants in Lighthouse Hill, Staten Island:0
# ( 294 / 306 ) Japanese Resturants in Richmond Valley, Staten Island:1
# ( 295 / 306 ) Japanese Resturants in Malba, Queens:1
# ( 296 / 306 ) Japanese Resturants in Highland Park, Brooklyn:0
# ( 297 / 306 ) Japanese Resturants in Madison, Brooklyn:0
# ( 298 / 306 ) Japanese Resturants in Bronxdale, Bronx:0
# ( 299 / 306 ) Japanese Resturants in Allerton, Bronx:0
# ( 300 / 306 ) Japanese Resturants in Kingsbridge Heights, Bronx:0
# ( 301 / 306 ) Japanese Resturants in Erasmus, Brooklyn:0
# ( 302 / 306 ) Japanese Resturants in Hudson Yards, Manhattan:0
# ( 303 / 306 ) Japanese Resturants in Hammels, Queens:0
# ( 304 / 306 ) Japanese Resturants in Bayswater, Queens:0
# ( 305 / 306 ) Japanese Resturants in Queensbridge, Queens:0
# ( 306 / 306 ) Japanese Resturants in Fox Hills, Staten Island:0

# %%
japanese_rest_ny.shape
# Out:
# (190, 4)

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Japanese Resturants for each Borough in New York City')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('No.of Japanese Resturants', fontsize=15)
#giving a bar plot
japanese_rest_ny.groupby('Borough')['ID'].count().plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Number of Japanese Resturants for each Neighborhood in New York City')
#On x-axis
plt.xlabel('Neighborhood', fontsize = 15)
#On y-axis
plt.ylabel('No.of Japanese Resturants', fontsize=15)
#giving a bar plot
japanese_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(5).plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()

# %%
def get_venue_details(venue_id):
    
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
japanese_rest_stats_ny=pd.DataFrame(columns=column_names)
count=1


for row in japanese_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(japanese_rest_ny),')','processed')
    japanese_rest_stats_ny = japanese_rest_stats_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
# Out:
#                          ID                      Name  Likes  Rating  Tips
# 0  503cfaffe4b066d39de5005a  Aoyu Japanese Restaurant     32     9.0    19
# ( 1 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4b0b311af964a520642e23e3  Palace of Japan     38     8.5    26
# ( 2 / 190 ) processed
#                          ID                      Name  Likes  Rating  Tips
# 0  503cfaffe4b066d39de5005a  Aoyu Japanese Restaurant     32     9.0    19
# ( 3 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4b0b311af964a520642e23e3  Palace of Japan     38     8.5    26
# ( 4 / 190 ) processed
#                          ID                                         Name  \
# 0  4dbdf3d790a02849cbd675be  Ohana Japanese Habachi Seafood & Steakhouse
#
#    Likes  Rating  Tips
# 0     34     7.7    18
# ( 5 / 190 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  5d40d7a398a00a0008b4c8ca  Benihana      0     7.6     0
# ( 6 / 190 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 5c79cb8360255e002c86ffaf
# ( 7 / 190 ) processed
#                          ID                      Name  Likes  Rating  Tips
# 0  503cfaffe4b066d39de5005a  Aoyu Japanese Restaurant     32     9.0    19
# ( 8 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4b0b311af964a520642e23e3  Palace of Japan     38     8.5    26
# ( 9 / 190 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  54e0efc3498e7eda5dff1847  Sarku     16     7.9     5
# ( 10 / 190 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4b33fd94f964a520842325e3  Arirang Hibachi Steakhouse     76     7.6    21
# ( 11 / 190 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  51f42bb3498e2681264e00a1  Kasumi Sushi & BBQ Restaurant      6     7.4
#
#    Tips
# 0     3
# ( 12 / 190 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4b787863f964a52080d02ee3  Shiki Japanese Hibachi      6     7.2     2
# ( 13 / 190 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  513e7ec8e4b07f4fa1b53b3d  Fuki Sushi Japanese Restaurant     11     7.2
#
#    Tips
# 0     1
# ( 14 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4c326b9fa0ced13ac126156e  Ichi Sushi     15     6.6     8
# ( 15 / 190 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  5e4c841b1485b40007d77e6e  Rule Of Thirds     16     8.6     3
# ( 16 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4d6adae62ea9b1f7cb22ca28  Fuji Hana     10     7.6     4
# ( 17 / 190 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  5236313711d25d0f9d3f3b67  Momo Hibachi Steak House & Bar     22     7.5
#
#    Tips
# 0     6
# ( 18 / 190 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4baab031f964a520fc7f3ae3  Chikurin Japanese Restaurant     34     7.2    14
# ( 19 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  4bf890acabdaef3b69b7a184  Masake      6     6.2     6
# ( 20 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4e8e51a86c255231f540bad1  Sushi Spot     13     7.4     7
# ( 21 / 190 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4d1004a56331a0930a505494  Sakura Tokyo     23     7.7    19
# ( 22 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5091d1ffe4b0f08bb9df6701  Masago Bistro     11     6.5     7
# ( 23 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4d5c12a01e43236a87eb1583  Sake Sushi     31     7.7    49
# ( 24 / 190 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  5cb5e5f9a35f4600255406c6  Maison Yaki     81     8.3    23
# ( 25 / 190 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  41478600f964a520c41c1fe3  Geido    247     8.7    83
# ( 26 / 190 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  51f9b7b3498eefe896caeb23  Shalom Japan    298     8.2    99
# ( 27 / 190 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4c7f0887fb74236a7727f9b9  Samurai Mama    899     8.9   244
# ( 28 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5b3bcb69bfc6d0002ca9bf17  Warude     26     8.1     5
# ( 29 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  479ccb47f964a5206b4d1fe3  Iron Chef House    143     8.1    66
# ( 30 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  48a41073f964a52091511fe3  Hibino    486     9.1   157
# ( 31 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  48a41073f964a52091511fe3  Hibino    486     9.1   157
# ( 32 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5739c66c498e7ef6085cec4f  Karasu    203     8.7    35
# ( 33 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5276d39a498eb1a5d90096e4  Sushi Katsuei    246     9.0    81
# ( 34 / 190 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  41478600f964a520c41c1fe3  Geido    247     8.7    83
# ( 35 / 190 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 55bbd332498ea08332b67e48
# ( 36 / 190 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  5236313711d25d0f9d3f3b67  Momo Hibachi Steak House & Bar     22     7.5
#
#    Tips
# 0     6
# ( 37 / 190 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  51f42bb3498e2681264e00a1  Kasumi Sushi & BBQ Restaurant      6     7.4
#
#    Tips
# 0     3
# ( 38 / 190 ) processed
#                          ID                    Name  Likes  Rating  Tips
# 0  4b787863f964a52080d02ee3  Shiki Japanese Hibachi      6     7.2     2
# ( 39 / 190 ) processed
#                          ID                            Name  Likes  Rating  \
# 0  513e7ec8e4b07f4fa1b53b3d  Fuki Sushi Japanese Restaurant     11     7.2
#
#    Tips
# 0     1
# ( 40 / 190 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0
) processed
#                          ID      Name  Likes  Rating  Tips
# 0  51de06aa498e998d374ab4da  Hirohisa     74     8.9    28
# ( 91 / 190 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  42055e00f964a5206e1f1fe3  EN Japanese Brasserie    618     8.9   262
# ( 92 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  5d8d6185e26fad00092dbd2f  Nami Nori     68     9.2    15
# ( 93 / 190 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  5d8eaad4f09f8d0008f23cd5  Moonrise Izakaya     10     7.8     3
# ( 94 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  581a10901df6b32e66ec3a07  Sugarfish    455     8.8   102
# ( 95 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4b60c708f964a520d0f829e3  Nobu Downtown    270     8.7    84
# ( 96 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4b60c708f964a520d0f829e3  Nobu Downtown    270     8.7    84
# ( 97 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  585c15782b04f80cdd0e9711  Kome Waza     93     8.4    26
# ( 98 / 190 ) processed
#                          ID              Name  Likes  Rating  Tips
# 0  5c8c36363af988002c811da1  Mochiron Izakaya      9     8.2     3
# ( 99 / 190 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  59cfbbaf491be76b026b6a84  Matsuri      9     7.3     4
# ( 100 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  4c100cd3b93cc9b6482156e0  Hagane     13     6.3     4
# ( 101 / 190 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4bba1c4b1261d13a243cea98  Narita Japanese Restaurant     41     7.7    25
# ( 102 / 190 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  45da8cc4f964a520f8421fe3  Midori Matsu      9     6.9    14
# ( 103 / 190 ) processed
#                          ID                         Name  Likes  Rating  Tips
# 0  553ed373498e6aacce815a89  Iki Modern Japanese Cuisine     29     8.0     6
# ( 104 / 190 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  59332282fdb9a77bd81847b5  Gyu-Kaku Japanese BBQ     29     7.4     7
# ( 105 / 190 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  5a22f5b8d41bb773bfc3f5c3  Suzuki Shokudo     20     8.0     5
# ( 106 / 190 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4abebdcbf964a520a78f20e3  Ariyoshi Japanese Restaurant     90     8.0    28
# ( 107 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4c4653d8dd35be9ab0a4ddd8  Wakamatsu     17     7.0     8
# ( 108 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4ee7eaf7469064168cac36bf  Bamboo Ya     48     8.0    17
# ( 109 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4c6038b654ac0f4736f7b421  Akiyama™  Sushi      9     5.7     7
# ( 110 / 190 ) processed
#                          ID                              Name  Likes  Rating  \
# 0  4bf716a85317a5930e72fd7e  Takara Sushi Japanese Restaurant     29     7.9
#
#    Tips
# 0    16
# ( 111 / 190 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4cf1b6e98333224b19350c8e  Casa Asia Cuisine     13     7.4     7
# ( 112 / 190 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  4b05e38ff964a5202de522e3  Yamato Sushi      6     7.3     3
# ( 113 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  53696c9b498ef94c9f2bc134  Tei Nei Ya     15     8.0     7
# ( 114 / 190 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 59aae030fdb9a734ddf67239
# ( 115 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  53696c9b498ef94c9f2bc134  Tei Nei Ya     15     8.0     7
# ( 116 / 190 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 59aae030fdb9a734ddf67239
# ( 117 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  5801a5a238faa8f401a48ecd  Mira Sushi     14     6.2     5
# ( 118 / 190 ) processed
#                          ID                               Name  Likes  Rating  \
# 0  4d7926de930ef04da310c24f  Tokyo Hibachi Steak House & Sushi     17     6.8
#
#    Tips
# 0     8
# ( 119 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  5801a5a238faa8f401a48ecd  Mira Sushi     14     6.2     5
# ( 120 / 190 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  50f5979fe4b0ff6d3603e506  PP Boy Japan Teriyaki & Sushi      8     7.2
#
#    Tips
# 0     6
# ( 121 / 190 ) processed
#                          ID                              Name  Likes  Rating  \
# 0  4bf716a85317a5930e72fd7e  Takara Sushi Japanese Restaurant     29     7.9
#
#    Tips
# 0    16
# ( 122 / 190 ) processed
#                          ID               Name  Likes  Rating  Tips
# 0  4cf1b6e98333224b19350c8e  Casa Asia Cuisine     13     7.4     7
# ( 123 / 190 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  4bc8eee83740b713fcbe5d65  Northern Sushi      6     7.8     2
# ( 124 / 190 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  5cf07afa66f3cd002c8b3ae6  Izakaya Mew      7     7.1     1
# ( 125 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5501cbe6498e4f463c238485  Nikko Hibachi     22     8.4     4
# ( 126 / 190 ) processed
#                          ID                       Name  Likes  Rating  Tips
# 0  4b6f3283f964a520ace32ce3  Izumi Japanese Restaurant     13     7.6    11
# ( 127 / 190 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  54e52f13498e7116ea0cb0d0  Kondo     46     9.0    11
# ( 128 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  4b9ae1e3f964a52030df35e3  Kawaii     20     8.8     8
# ( 129 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4ee7eaf7469064168cac36bf  Bamboo Ya     48     8.0    17
# ( 130 / 190 ) processed
#                          ID                Name  Likes  Rating  Tips
# 0  4c3b4ae416cb2d7f8b9c02a9  Tomo Japanese Cafe     64     8.1    33
# ( 131 / 190 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  4b5b135df964a52057e228e3  Katsuno     43     8.1    23
# ( 132 / 190 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4bba1c4b1261d13a243cea98  Narita Japanese Restaurant     41     7.7    25
# ( 133 / 190 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  4fbfb2ece4b0a6eab8ea41b8  Fuji Japanese Cuisine     25     7.2     5
# ( 134 / 190 ) processed
#                          ID          Name  Likes  Rating  Tips
# 0  45da8cc4f964a520f8421fe3  Midori Matsu      9     6.9    14
# ( 135 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4bca626368f976b086615f83  Kyoto Sushi 5      4     6.6     5
# ( 136 / 190 ) processed
#                          ID                  Name  Likes  Rating  Tips
# 0  4d06abf2c2e5370451f1c467  Tokyo Sushi Japanese      6     6.5     3
# ( 137 / 190 ) processed
#                          ID                        Name  Likes  Rating  Tips
# 0  4b747a21f964a520e6de2de3  Arirang Hibachi Steakhouse     51     7.7    11
# ( 138 / 190 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4b9863e0f964a520a83f35e3
# ( 139 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4e8e51a86c255231f540bad1  Sushi Spot     13     7.4     7
# ( 140 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4bad3dcbf964a520173d3be3  Fuji Sushi      9     8.1     6
# ( 141 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4bad3dcbf964a520173d3be3  Fuji Sushi      9     8.1     6
# ( 142 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  4ba57c41f964a520c60b39e3  Nakata     31     8.2    23
# ( 143 / 190 ) processed
#                          ID                         Name  Likes  Rating  Tips
# 0  4e4e4a61bd4101d0d7a6f56f  Fushimi Japanese Restaurant     26     7.2     9
# ( 144 / 190 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4ba6aeadf964a5208d6839e3  Hokkaido Japanese Restaurant      9     7.4     5
# ( 145 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4bc898de15a7ef3b40697bda  Buddha Lounge     11     5.9    14
# ( 146 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4b79eec8f964a520161b2fe3  Sapporo Sushi     15     6.8    13
# ( 147 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  4b3fdfc8f964a5200ab125e3  Ichiro    104     8.5    51
# ( 148 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  57a3bda338fa6612ad9c17f2  Secchu Yokota     39     9.2    10
# ( 149 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  5b3805910dd31f002409405a  Suki Curry     54     9.2    14
# ( 150 / 190 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  4a02e66ff964a52073711fe3  Bohemian    387     9.0   181
# ( 151 / 190 ) processed
#                          ID  Name  Likes  Rating  Tips
# 0  510c85e7e4b0056826b88297  Kura    213     9.2    62
# ( 152 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4b60c708f964a520d0f829e3  Nobu Downtown    270     8.7    84
# ( 153 / 190 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  51e8ce40498ea1fb0180efb2  Izakaya MEW   1054     8.9   266
# ( 154 / 190 ) processed
#                          ID                                  Name  Likes  \
# 0  58b8ed467220e661ddf34104  KazuNori: The Original Hand Roll Bar    520
#
#    Rating  Tips
# 0     9.1   125
# ( 155 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5ad925da2f97ec3e4b17eba2  Nonono    150     8.7    26
# ( 156 / 190 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4ba6aeadf964a5208d6839e3  Hokkaido Japanese Restaurant      9     7.4     5
# ( 157 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  4bad3dcbf964a520173d3be3  Fuji Sushi      9     8.1     6
# ( 158 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4bca626368f976b086615f83  Kyoto Sushi 5      4     6.6     5
# ( 159 / 190 ) processed
#                          ID   Name  Likes  Rating  Tips
# 0  4d7fc91f95c1a143260eecf2  Yoshi      7     7.4     7
# ( 160 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  4bfc3f24b5cd2d7fc34931fb  Sosaku      4     7.0     5
# ( 161 / 190 ) processed
# Empty DataFrame
# Columns: [ID, Name, Likes, Rating, Tips]
# Index: []
# No data available for id= 4db5c4dacda1c57c8275e417
# ( 162 / 190 ) processed
#                          ID                           Name  Likes  Rating  \
# 0  50f5979fe4b0ff6d3603e506  PP Boy Japan Teriyaki & Sushi      8     7.2
#
#    Tips
# 0     6
# ( 163 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  5501cbe6498e4f463c238485  Nikko Hibachi     22     8.4     4
# ( 164 / 190 ) processed
#                          ID                       Name  Likes  Rating  Tips
# 0  4b6f3283f964a520ace32ce3  Izumi Japanese Restaurant     13     7.6    11
# ( 165 / 190 ) processed
#                          ID                               Name  Likes  Rating  \
# 0  4d7926de930ef04da310c24f  Tokyo Hibachi Steak House & Sushi     17     6.8
#
#    Tips
# 0     8
# ( 166 / 190 ) processed
#                          ID                     Name  Likes  Rating  Tips
# 0  4b817770f964a520ffa730e3  Futigi Japanese Cuisine      3     5.9     7
# ( 167 / 190 ) processed
#                          ID                     Name  Likes  Rating  Tips
# 0  4b817770f964a520ffa730e3  Futigi Japanese Cuisine      3     5.9     7
# ( 168 / 190 ) processed
#                          ID        Name  Likes  Rating  Tips
# 0  52b470f511d2522f86497c9b  Hibino LIC    194     9.2    52
# ( 169 / 190 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  5718e217498e458de03e94c8  Takumen    179     9.0    53
# ( 170 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  5bb7e3ced48ec100398ab4fb  Dai Hachi      9     8.9     6
# ( 171 / 190 ) processed
#                          ID                   Name  Likes  Rating  Tips
# 0  48208c8cf964a520894f1fe3  Gyu-Kaku Japanese BBQ    486     8.5   161
# ( 172 / 190 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  536ee0fb498e265dd8cb4a93  Tsushima     69     7.8    15
# ( 173 / 190 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  559cbaa6498eaa4e8d884811  Tempura Matsui     47     8.5    11
# ( 174 / 190 ) processed
#                          ID     Name  Likes  Rating  Tips
# 0  4a99b4f4f964a520f62f20e3  Kajitsu    186     8.7    70
# ( 175 / 190 ) processed
#                          ID            Name  Likes  Rating  Tips
# 0  591caee89deb7d0f69be77a2  Omusubi Gonbei     14     8.4     1
# ( 176 / 190 ) processed
#                          ID      Name  Likes  Rating  Tips
# 0  536ee0fb498e265dd8cb4a93  Tsushima     69     7.8    15
# ( 177 / 190 ) processed
#                          ID  Name  Likes  Rating  Tips
# 0  510c85e7e4b0056826b88297  Kura    213     9.2    62
# ( 178 / 190 ) processed
#                          ID  Name  Likes  Rating  Tips
# 0  5bd7a5561c675b0039be9acc  HALL     57     9.2    10
# ( 179 / 190 ) processed
#                          ID                 Name  Likes  Rating  Tips
# 0  4f7b61f6e4b07aaa5d524842  OOTOYA 大戸屋 (OOTOYA)   1221     9.0   274
# ( 180 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  581a10901df6b32e66ec3a07  Sugarfish    455     8.8   102
# ( 181 / 190 ) processed
#                          ID                          Name  Likes  Rating  Tips
# 0  4abebdcbf964a520a78f20e3  Ariyoshi Japanese Restaurant     90     8.0    28
# ( 182 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5cf1562460255e002c5e683c  Bessou     11     8.2     1
# ( 183 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5cf1562460255e002c5e683c  Bessou     11     8.2     1
# ( 184 / 190 ) processed
#                          ID    Name  Likes  Rating  Tips
# 0  5cf1562460255e002c5e683c  Bessou     11     8.2     1
# ( 185 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  479ccb47f964a5206b4d1fe3  Iron Chef House    143     8.1    66
# ( 186 / 190 ) processed
#                          ID       Name  Likes  Rating  Tips
# 0  4d6adae62ea9b1f7cb22ca28  Fuji Hana     10     7.6     4
# ( 187 / 190 ) processed
#                          ID         Name  Likes  Rating  Tips
# 0  4bfb16ebd2b720a16395326a  Omiya Sushi     13     7.4     2
# ( 188 / 190 ) processed
#                          ID           Name  Likes  Rating  Tips
# 0  4bc898de15a7ef3b40697bda  Buddha Lounge     11     5.9    14
# ( 189 / 190 ) processed
#                          ID             Name  Likes  Rating  Tips
# 0  4c6038b654ac0f4736f7b421  Akiyama™  Sushi      9     5.7     7
# ( 190 / 190 ) processed

# %%
japanese_rest_stats_ny.to_csv('japanese_rest_stats_ny.csv', index=False)

# %%
japanese_rest_stats_ny_csv=pd.read_csv('japanese_rest_stats_ny.csv')

# %%
japanese_rest_stats_ny_csv.head()
# Out:
#   Borough Neighborhood                        ID  \
# 0   Bronx    Riverdale  503cfaffe4b066d39de5005a
# 1   Bronx    Riverdale  4b0b311af964a520642e23e3
# 2   Bronx  Kingsbridge  503cfaffe4b066d39de5005a
# 3   Bronx  Kingsbridge  4b0b311af964a520642e23e3
# 4   Bronx  City Island  4dbdf3d790a02849cbd675be
#
#                                           Name  Likes  Rating  Tips
# 0                     Aoyu Japanese Restaurant     32     9.0    19
# 1                              Palace of Japan     38     8.5    26
# 2                     Aoyu Japanese Restaurant     32     9.0    19
# 3                              Palace of Japan     38     8.5    26
# 4  Ohana Japanese Habachi Seafood & Steakhouse     34     7.7    18

# %%
japanese_rest_stats_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       190 non-null    object
#  1   Neighborhood  190 non-null    object
#  2   ID            190 non-null    object
#  3   Name          190 non-null    object
#  4   Likes         190 non-null    object
#  5   Rating        190 non-null    float64
#  6   Tips          190 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 10.5+ KB

# %%
japanese_rest_stats_ny['Likes']=japanese_rest_stats_ny['Likes'].astype('float64')
japanese_rest_stats_ny['Tips']=japanese_rest_stats_ny['Tips'].astype('float64')

# %%
japanese_rest_stats_ny.iloc[japanese_rest_stats_ny['Likes'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                    Flatiron
# ID              4f7b61f6e4b07aaa5d524842
# Name                 OOTOYA 大戸屋 (OOTOYA)
# Likes                               1221
# Rating                                 9
# Tips                                 274
# Name: 179, dtype: object

# %%
japanese_rest_stats_ny.iloc[japanese_rest_stats_ny['Rating'].idxmax()]
# Out:
# Borough                         Brooklyn
# Neighborhood           East Williamsburg
# ID              52517e05498ec2e28c792fa2
# Name               Brooklyn Ball Factory
# Likes                                298
# Rating                               9.2
# Tips                                  89
# Name: 57, dtype: object

# %%
japanese_rest_stats_ny.iloc[japanese_rest_stats_ny['Tips'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                     Chelsea
# ID              454f7cc4f964a520dc3c1fe3
# Name                            Morimoto
# Likes                                792
# Rating                               8.7
# Tips                                 353
# Name: 84, dtype: object

# %%
ny_neighborhood_stats=japanese_rest_stats_ny.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
ny_neighborhood_stats.columns=['Neighborhood','Average Rating']

# %%
ny_neighborhood_stats.sort_values(['Average Rating'],ascending=False).head(10)
# Out:
#           Neighborhood  Average Rating
# 67     Lower East Side        9.200000
# 31        East Village        9.200000
# 98     Stuyvesant Town        9.200000
# 80                Noho        9.150000
# 22         Cobble Hill        9.100000
# 108       West Village        9.050000
# 50   Greenwich Village        9.050000
# 56       Hunters Point        9.033333
# 87          Ravenswood        9.000000
# 35            Flatiron        9.000000

# %%
ny_borough_stats=japanese_rest_stats_ny.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
ny_borough_stats.columns=['Borough','Average Rating']

# %%
ny_borough_stats.sort_values(['Average Rating'],ascending=False).head()
# Out:
#          Borough  Average Rating
# 2      Manhattan        8.671429
# 0          Bronx        7.570000
# 1       Brooklyn        7.519118
# 3         Queens        7.210417
# 4  Staten Island        6.700000

# %%
plt.figure(figsize=(9,5), dpi = 100)
# title
plt.title('Average rating of Japanese Resturants for Top 5 Boroughs')
#On x-axis
plt.xlabel('Borough', fontsize = 15)
#On y-axis
plt.ylabel('Average Rating', fontsize=15)
#giving a bar plot
japanese_rest_stats_ny.groupby('Borough').mean()['Rating'].plot(kind='bar')
#legend
plt.legend()
#displays the plot
plt.show()
